# %%
import pandas as pd

data = []
for i in range(0, 8):
    filename = f'./../../data/raw/migros_stores_data_{i}.csv'
    data.append(pd.read_csv(filename))
    # print(filename)
    # print(data[i].info())
    print(data[i].head())
    
df = pd.concat(data, ignore_index=True)
df.drop_duplicates()
df.to_csv('./../../data/processed/migros_stores_data.csv')
df

# data0 = pd.read_csv('./../../data/raw/migros_stores_data_0.csv')
# data1 = pd.read_csv('./../../data/raw/migros_stores_data_1.csv')

# print(data0.info())
# print(data1.info())
# data1 = data1.dropna(axis=1)
# merged = data0.merge(data1, on='title')
# merged.to_csv("output.csv", index=False)
# data0
# Out:
#       Unnamed: 0        unique_id       osmid element_type addr:housenumber  \
# 0              0   node/355287954   355287954         node               32
# 1              1   node/357276931   357276931         node              NaN
# 2              2   node/357299653   357299653         node              NaN
# 3              3   node/454026916   454026916         node              NaN
# 4              4   node/886099069   886099069         node              NaN
# ...          ...              ...         ...          ...              ...
# 2975         525  node/1263651484  1263651484         node                9
# 2976         526  node/1654123463  1654123463         node              191
# 2977         527  node/1738448253  1738448253         node               71
# 2978         528  node/5718170409  5718170409         node               31
# 2979         529     way/23887584    23887584          way               17
#
# ...
