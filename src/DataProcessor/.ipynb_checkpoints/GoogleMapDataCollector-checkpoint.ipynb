# %%
import json
import requests
import yaml
import pandas as pd
from pandas import concat
from datetime import datetime
from pandas import json_normalize

# %%
### Get list of commune
# https://www.bfs.admin.ch/bfs/en/home/statistics/catalogues-databases/tables.assetdetail.16484444.html
commune_df = pd.read_csv("./../../data/raw/RegionalPortraits21.03.01.csv", sep=';', low_memory=False)
commune_df = commune_df[['REGION', 'VALUE']]

# for row in commune_df.iterrows():
#     region = row[1]['REGION'] # Region 
#     population = row[1]['VALUE'] # Population
#     print(f'Region = `{region}`, Population = `{population}`')
    
commune_df
# Out:
#                   REGION  VALUE
# 0        Aeugst am Albis   1981
# 1     Affoltern am Albis  12303
# 2             Bonstetten   5572
# 3        Hausen am Albis   3751
# 4               Hedingen   3778
# ...                  ...    ...
# 2167        Vendlincourt    559
# 2168       Basse-Allaine   1238
# 2169       Clos du Doubs   1263
# 2170         Haute-Ajoie   1085
# 2171          La Baroche   1142
#
# [2172 rows x 2 columns]

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

# actual api key
config = yaml.load(open("./../../credentials.yml"), Loader=yaml.FullLoader)
gmaps_key = config["google_map_key"]

# get method of requests module, return response object
i = 0
for row in commune_df.iterrows():
    region = row[1]['REGION'] # Region | Commune
    
    # text string on which to search
    query = f'supermarket {region} Switzerland' #input("Search query: ")
    
    df = pd.DataFrame()
    next_page_token = None
    while True:
        req = requests.get(url + "query=" + query + "&key=" + gmaps_key + ('' if next_page_token == None else f'&pageToken={next_page_token}'))

        # json method of response object: json format data -> python format data
        places_json = req.json()

        # process request response
        for result in places_json['results']:
            df = pd.concat([df, json_normalize(result)], ignore_index=True)
            #df.loc[df.astype(str).drop_duplicates().index] # otherwise will be TypeError: unhashable type: 'list'

        # inform an request has been processed
        # print(f"{i} - A request has been processed at", datetime.now().strftime("%H:%M:%S"))
        i += 1

        if ('next_page_token' in places_json.keys()):
            next_page_token = places_json['next_page_token']
        else:
            df.loc[df.astype(str).drop_duplicates().index]
            df.to_csv(f"./../../data/raw/gmaps_data_{region}.csv")
            print(f"{i}./../../data/raw/gmaps_data_{region}.csv created at", datetime.now().strftime("%H:%M:%S"))
            break
print('done!')

# %%
original_df = pd.read_csv("./../../data/raw/gmaps_data.csv", low_memory=False)
df = original_df[['formatted_address', 'name', 'rating', 'types', 'user_ratings_total', 'geometry.location.lat', 'geometry.location.lng', 'plus_code.compound_code']].copy()

df['canton'] = df.apply(lambda row: row.formatted_address.split(',')[1][6:], axis=1)
df.to_csv("./../../data/processed/gmaps_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 original_df = pd.read_csv("./../../data/raw/gmaps_data.csv", low_memory=False)
#       2 df = original_df[['formatted_address', 'name', 'rating', 'types', 'user_ratings_total', 'geometry.location.lat', 'geometry.location.lng', 'plus_code.compound_code']].copy()
#       4 df['canton'] = df.apply(lambda row: row.formatted_address.split(',')[1][6:], axis=1)
#
# NameError: name 'pd' is not defined

# %%
grouped_df = df.groupby(by=['canton', 'name']).agg({
    'rating': ['mean', 'median', 'count'],
    'user_ratings_total': 'sum',
    'geometry.location.lat': 'count'
}).rename(columns={
    'rating_count': 'count'
}).reset_index()

grouped_df[grouped_df['name'] == 'Migros']
grouped_df

#df.groupby(["item", "color"])["id"].count().reset_index(name="count")
# Out:
#                    canton                                    name rating  \
#                                                                     mean
# 0                    Bern        Coop Supermarkt Bern Spitalgasse    4.1
# 1                    Bern                       Migros Supermarkt    4.1
# 2                  Ebikon                                Bachmann    3.7
# 3                  Ebikon                         Denner Discount    4.1
# 4               Engelberg                                    Coop    4.2
# 5                  Giswil                  Coop Supermarkt Giswil    4.3
# 6                  Giswil                       Valora Schweiz AG    0.0
# 7              Interlaken                                    ALDI    4.2
# 8              Interlaken      Coop Supermarkt Interlaken Bahnhof    4.3
# 9              Interlaken          Coop Supermarkt Interlaken Ost    4.3
# 10             Interlaken                                  Migros    4.4
# 11                 Kloten       Migros Supermarket Zurich Airport    4.5
# 12                 Kriens                      Maximum Supermarkt    4.4
# 13  Matten bei Interlaken                         Lidl Interlaken    4.2
# 14              Meiringen                       Migros Supermarkt    4.4
# 15                 Mürren                  Coop Supermarkt Mürren    4.3
# 16                Opfikon                                    ALDI    4.3
# 17              Schlieren  Aligro Schlieren - Wholesaler for food    4.4
# 18             St. Moritz     Coop Supermarkt St. Moritz Bellevue    4.4
# 19             St. Moritz         Coop Supermarkt St. Moritz-Dorf    4.2
# 20                  Stans                       Migros Supermarkt    4.5
# 21              Wengen BE                  Coop Supermarkt Wengen    4.2
# 22              Wädenswil               International Supermarket    5.0
# 23                Zermatt                 Coop Supermarkt Zermatt    4.2
# 24                Zermatt                       Migros Supermarkt    4.3
# 25                 Zürich                             ALDI SUISSE    4.2
# 26                 Zürich                                    Aldi    4.3
# 27                 Zürich                                    Coop    4.3
# 28                 Zürich    Coop Supermarkt Zürich Bahnhofbrücke    4.3
# 29                 Zürich           Fresh Shop Supermarkt-Seebach    4.2
# 30                 Zürich                      Indiasupermarkt.ch    4.5
# 31                 Zürich                        LIDL Switzerland    4.4
# 32                 Zürich                           ShopVilleMärt    5.0
# 33                 Zürich                                YumiHana    4.4
# 34                 Zürich                 coop Zürich Stadelhofen    4.2
#
#                 user_ratings_total geometry.location.lat
#    median count                sum                 count
# 0     4.1  2190             707370                  2190
# 1     4.1  2933             615930                  2933
# 2     3.7     1                 67                     1
# 3     4.1  2191              32865                  2191
# 4     4.2  3230            2157640                  3230
# 5     4.3     1                186                     1
# 6     0.0     1                  0                     1
# 7     4.2  3230            2261000                  3230
# 8     4.3  1039             274296                  1039
# 9     4.3   296             210752                   296
# 10    4.4  3229            5970421                  3229
# 11    4.5  2486            4293322                  2486
# 12    4.4  2190              87600                  2190
# 13    4.2  3229            3157962                  3229
# 14    4.4  1039             453004                  1039
# 15    4.3  3066             978054                  3066
# 16    4.3  2190            1364370                  2190
# 17    4.4  1039             554826                  1039
# 18    4.4  1039            1505511                  1039
# 19    4.2   163              58191                   163
# 20    4.5     1                759                     1
# 21    4.2  3229            1013906                  3229
# 22    5.0  2933             117320                  2933
# 23    4.2  2190            1830840                  2190
# 24    4.3  1039             716910                  1039
# 25    4.2  4269            3054608                  4269
# 26    4.3  3230            3230000                  3230
# 27    4.3  3230             268090                  3230
# 28    4.3  3229           10239159                  3229
# 29    4.2  1039             488330                  1039
# 30    4.5  2191             333032                  2191
# 31    4.4  3230            3307520                  3230
# 32    5.0     1                  1                     1
# 33    4.4     1                570                     1
# 34    4.2     1                530                     1
