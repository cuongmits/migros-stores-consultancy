# %%
import json
import requests
import yaml
import pandas as pd
from pandas import concat
from datetime import datetime

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

# text string on which to search
query = 'supermarket in Switzerland' #input("Search query: ")

# actual api key
config = yaml.load(open("./../../credentials.yml"), Loader=yaml.FullLoader)
gmaps_key = config["google_map_key"]

# get method of requests module, return response object
df = pd.DataFrame()
next_page_token = None
while True:
    req = requests.get(url + "query=" + query + "&key=" + gmaps_key + ('' if next_page_token == None else f'&pageToken={next_page_token}'))
    
    # json method of response object: json format data -> python format data
    places_json = req.json()
    
    # process request response
    for result in places_json['results']:
        df = pd.concat([df, json_normalize(result)], ignore_index=True)
    
    # inform an request has been processed
    print("A request has been processed at ", datetime.now().strftime("%H:%M:%S"))
    
    next_page_token = places_json['next_page_token']
    if next_page_token == None:
        break

df.to_csv("./../../data/processed/gmaps_data.csv")
df

# # now result contains list of nested dictionaries
# my_result = places_json["results"]

# # take a look at the first element
# my_result[0]
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL          Bahnhofbrücke 1, 8001 Zürich, Switzerland
# 1      OPERATIONAL   Rugenparkstrasse 1, 3800 Interlaken, Switzerland
# 2      OPERATIONAL            Museumstrasse, 8001 Zürich, Switzerland
# 3      OPERATIONAL       Titliszentrum 5, 6390 Engelberg, Switzerland
# 4      OPERATIONAL           Zollstrasse 58, 8005 Zürich, Switzerland
# 5      OPERATIONAL            Bahnhofpl. 6, 3920 Zermatt, Switzerland
# 6      OPERATIONAL    Fraumünsterstrasse 16, 8001 Zürich, Switzerland
# 7      OPERATIONAL         Flughofstrasse 3, 8058 Kloten, Switzerland
# 8      OPERATIONAL          Borthalten 1032, 3825 Mürren, Switzerland
# 9      OPERATIONAL       Wengiboden 1347, 3823 Wengen BE, Switzerland
# 10     OPERATIONAL      Lindenallee 106, 3800 Interlaken, Switzerland
# 11     OPERATIONAL          Hohlstrasse 473, 8048 Zürich, Switzerland
# ...
